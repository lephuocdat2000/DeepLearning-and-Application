# %% [markdown]
# <a href="https://colab.research.google.com/github/lephuocdat2000/DeepLearning-and-Application/blob/main/SER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np

# %% [markdown]
# ###Extract file name and label

# %%
data_path = '/content/drive/MyDrive/Nhận dạng/Data Voice'
emotions=os.listdir(data_path)
filenames = []
labels = []
for emotion in emotions:
   file_names = os.listdir(os.path.join(data_path,emotion))
   for name in file_names:
     if name!='transcript': 
         filenames.append(name.split(".")[0])
         labels.append(np.float(name[0]))

labels = np.array(labels)

# %% [markdown]
# ###Build audio vector

# %%
import librosa
from numpy import save
import librosa.display
import matplotlib.pyplot as plt
from numpy import load

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
audio_vectors = []
for idx,name in enumerate(filenames):
    emotion_path = os.path.join(data_path,emotions[int(labels[idx])])
    file_path = os.path.join(emotion_path,name+'.wav')
    y,sr = librosa.load(file_path, sr=44100)
    audio_vectors.append(y)

audio_vectors = np.array(audio_vectors)
#save to reuse
save('audio_vectors.npy',audio_vectors)

# %% [markdown]
# Test thử trên 1 audio

# %%
sr=44100 
y = audio_vectors[0]
plt.figure(figsize=(15,2))
librosa.display.waveplot(y, sr=sr, max_sr=1000, alpha=0.25, color='r')

# %%
rmse = librosa.feature.rms(y + 0.0001)[0]
plt.figure(figsize=(15,2))
plt.plot(rmse)
plt.ylabel('RMSE')
print('RMSE mean = {:.5f}'.format(np.mean(rmse)))
print('RMSE std dev = {:.5f}'.format(np.std(rmse)))
# Out:
# RMSE mean = 0.00859
# RMSE std dev = 0.00671

# %% [markdown]
# Chạy trên toàn bộ audio

# %%
def extract_audio_features(audio_vectors):
  audio_features = []
  for y in audio_vectors:
    features = []
    sig_mean = np.mean(abs(y))
    features.append(sig_mean)
    features.append(np.std(y))
    rmse = librosa.feature.rms(y + 0.0001)[0]
    features.append(np.mean(rmse))  # rmse_mean
    features.append(np.std(rmse))
    silence = 0
    for e in rmse:
      if e <= 0.4 * np.mean(rmse):
          silence += 1
    silence /= float(len(rmse))
    features.append(silence)  # silence
    y_harmonic = librosa.effects.hpss(y)[0]
    features.append(np.mean(y_harmonic) * 1000)  # harmonic (scaled by 1000)
    cl = 0.45 * sig_mean
    center_clipped = []
    for s in y:
      if s >= cl: center_clipped.append(s - cl)
      elif s <= -cl: center_clipped.append(s + cl)
      elif np.abs(s) < cl: center_clipped.append(0)
    auto_corrs = librosa.core.autocorrelate(np.array(center_clipped))
    features.append(1000 * np.max(auto_corrs)/len(auto_corrs))  # auto_corr_max (scaled by 1000)
    features.append(np.std(auto_corrs))  # auto_corr_std              
    audio_features.append(features)
  return audio_features

# %%
audio_vectors = load('audio_vectors.npy',allow_pickle=True)
audio_features = extract_audio_features(audio_vectors)
#Save audio_features
audio_features = np.array(audio_features)
save('audio_features.npy',audio_features)

# %% [markdown]
# #Split audio_feature

# %%
audio_features =load('audio_features.npy',allow_pickle=True)

# %%
from sklearn.model_selection import train_test_split
x_train_audio,x_test_audio,y_train,y_test = train_test_split(audio_features,labels,test_size=0.2,random_state=42)

# %% [markdown]
# Load feature

# %% [markdown]
# ###Extract Text feature

# %% [markdown]
# **Define preprocessing functions for text**

# %%
# !pip install underthesea
# Out:
# Collecting underthesea
#   Downloading https://files.pythonhosted.org/packages/a8/5f/03ab9091b88e7851aa92da33f8eea6f111423cc1194cf1636c63c1fff3d0/underthesea-1.3.1-py3-none-any.whl (7.5MB)
#      |████████████████████████████████| 7.5MB 5.3MB/s
# Collecting torch<=1.5.1,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/a4/cf/007b6de316c9f3d4cb315a60c308342cc299e464167f5ebc369e93b5e23a/torch-1.5.1-cp37-cp37m-manylinux1_x86_64.whl (753.2MB)
#      |████████████████████████████████| 753.2MB 22kB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from underthesea) (7.1.2)
# Collecting python-crfsuite>=0.9.6
#   Downloading https://files.pythonhosted.org/packages/79/47/58f16c46506139f17de4630dbcfb877ce41a6355a1bbf3c443edb9708429/python_crfsuite-0.9.7-cp37-cp37m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 33.7MB/s
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 51.0MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from underthesea) (3.13)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from underthesea) (1.0.1)
# Collecting transformers<=3.5.1,>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/3a/83/e74092e7f24a08d751aa59b37a9fc572b2e4af3918cb66f7766c3affb1b4/transformers-3.5.1-py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 32.1MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from underthesea) (3.2.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from underthesea) (0.22.2.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from underthesea) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from underthesea) (2.23.0)
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz (43kB)
#      |████████████████████████████████| 51kB 8.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch<=1.5.1,>=1.1.0->underthesea) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch<=1.5.1,>=1.1.0->underthesea) (0.16.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 30.8MB/s
# Collecting sentencepiece==0.1.91
#   Downloading https://files.pythonhosted.org/packages/f2/e2/813dff3d72df2f49554204e7e5f73a3dc0f0eb1e3958a4cad3ef3fb278b7/sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 30.7MB/s
# Collecting tokenizers==0.9.3
#   Downloading https://files.pythonhosted.org/packages/7b/ac/f5ba028f0f097d855e1541301e946d4672eb0f30b6e25cb2369075f916d2/tokenizers-0.9.3-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 37.3MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<=3.5.1,>=3.5.0->underthesea) (3.0.12)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers<=3.5.1,>=3.5.0->underthesea) (3.12.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<=3.5.1,>=3.5.0->underthesea) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<=3.5.1,>=3.5.0->underthesea) (2019.12.20)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->underthesea) (1.15.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (1.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers<=3.5.1,>=3.5.0->underthesea) (57.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<=3.5.1,>=3.5.0->underthesea) (2.4.7)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp37-none-any.whl size=16184 sha256=ccf4339d764c76c109ac0136e5dd82e00ee9120732687d61339f6a23330a708c
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.5.1 which is incompatible.
# ERROR: torchtext 0.10.0 has requirement torch==1.9.0, but you'll have torch 1.5.1 which is incompatible.
# Installing collected packages: torch, python-crfsuite, unidecode, sacremoses, sentencepiece, tokenizers, transformers, seqeval, underthesea
#   Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
# Successfully installed python-crfsuite-0.9.7 sacremoses-0.0.45 sentencepiece-0.1.91 seqeval-1.2.2 tokenizers-0.9.3 torch-1.5.1 transformers-3.5.1 underthesea-1.3.1 unidecode-1.2.0

# %%
import re
from underthesea import word_tokenize

strip_special_chars = re.compile("[^\w0-9 ]+")

def cleanSentences(string):
    string = string.lower().replace("<br />", " ")
    return re.sub(strip_special_chars, "", string)

# %% [markdown]
# Extract feature

# %%
text = []
vocab = dict()
max_length = 0
for idx,name in enumerate(filenames):
    emotion_path = os.path.join(data_path,emotions[int(labels[idx])])
    transcript_path = os.path.join(emotion_path,'transcript')
    file_path = os.path.join(transcript_path,name+'.txt')
    f = open(file_path,'r').read()
    f = word_tokenize(f,format='text')  
    f = cleanSentences(f)
    words = f.split()
    if max_length < len(words): max_length = len(words)
    for word in words:
       if word in vocab: vocab[word]+=1
       else: vocab[word]=1     
    text.append(f)

# %% [markdown]
# TFIDF

# %%
import tensorflow as tf
from tensorflow.keras import preprocessing 
from sklearn.feature_extraction.text import TfidfTransformer

tokenizer = preprocessing.text.Tokenizer()  
tokenizer.fit_on_texts( text ) 
tokenized_lines = tokenizer.texts_to_sequences(text) 
padded_lines = np.array(preprocessing.sequence.pad_sequences( tokenized_lines , maxlen=max_length , padding='post' ,))

transformer = TfidfTransformer(smooth_idf=False)
tfidf = transformer.fit_transform(padded_lines).toarray().astype('float64')

#savetfidf
save('tfidf.npy',tfidf)

# %% [markdown]
# ###Split tfidf

# %%
tfidf = load('tfidf.npy',allow_pickle=True)

# %%
x_train_text, x_test_text,y_train,y_test= train_test_split(tfidf,labels,test_size=0.2,random_state=42,)

# %% [markdown]
# #Combine Text+Audio

# %%
combined_x_train =np.concatenate((x_train_audio,x_train_text),axis=1)
combined_x_test = np.concatenate((x_test_audio,x_test_text),axis=1)

# %% [markdown]
# #Train

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score

class_names = np.unique(labels).astype('int')
emotion_labels = ['angry','happy','sad','neutral']

# %%
svc_classifier =SVC()
svc_classifier.fit(combined_x_train,y_train)

# Predict
y_pred = svc_classifier.predict(combined_x_test)
title = "Confusion matrix"
disp = plot_confusion_matrix(svc_classifier, combined_x_test, y_test,
                             display_labels=emotion_labels,
                             cmap=plt.cm.Blues,
                             normalize=None)
disp.ax_.set_title(title)
print(title)
plt.show()
 
print('Accuracy:',accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix
# Accuracy: 0.3625

# %%
rf_classifier = RandomForestClassifier(n_estimators=1200, min_samples_split=25)
rf_classifier.fit(combined_x_train, y_train)

# Predict
y_pred = rf_classifier.predict(combined_x_test)
title = "Confusion matrix"
disp = plot_confusion_matrix(rf_classifier, combined_x_test, y_test,
                             display_labels=emotion_labels,
                             cmap=plt.cm.Blues,
                             normalize=None)
disp.ax_.set_title(title)
print(title)
plt.show()
 
print('Accuracy:',accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix
# Accuracy: 0.5

# %%
import xgboost as xgb

xgb_classifier = xgb.XGBClassifier(max_depth=7, learning_rate=0.008, objective='multi:softprob', 
                                   n_estimators=1200, sub_sample=0.8, num_class=len(emotion_labels),
                                   booster='gbtree', n_jobs=4)
xgb_classifier.fit(combined_x_train, y_train)

# Predict
y_pred = xgb_classifier.predict(combined_x_test)
title = "Confusion matrix"
disp = plot_confusion_matrix(xgb_classifier, combined_x_test, y_test,
                             display_labels=emotion_labels,
                             cmap=plt.cm.Blues,
                             normalize=None)
disp.ax_.set_title(title)
print(title)
plt.show()
 
print('Accuracy:',accuracy_score(y_test, y_pred))

# %%
from sklearn.neural_network import MLPClassifier

mlp_classifier = MLPClassifier(hidden_layer_sizes=(650, ), activation='relu', solver='adam', alpha=0.0001,
                               batch_size='auto', learning_rate='adaptive', learning_rate_init=0.01,
                               power_t=0.5, max_iter=1000, shuffle=True, random_state=None, tol=0.0001,
                               verbose=False, warm_start=True, momentum=0.8, nesterovs_momentum=True,
                               early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999,
                               epsilon=1e-08)

mlp_classifier.fit(combined_x_train, y_train)

y_pred = mlp_classifier.predict(combined_x_test)
title = "Confusion matrix"
disp = plot_confusion_matrix(mlp_classifier, combined_x_test, y_test,
                             display_labels=emotion_labels,
                             cmap=plt.cm.Blues,
                             normalize=None)
disp.ax_.set_title(title)
print(title)
plt.show()
 
print('Accuracy:',accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix
# Accuracy: 0.5

# %%
ax = xgb.plot_importance(xgb_classifier, max_num_features=10, height=0.5, show_values=False)
fig = ax.figure
fig.set_size_inches(8, 8)

# %% [markdown]
# #Test thử data tiếng Anh

# %%
eng_data_path = '/content/drive/MyDrive/Nhận dạng/englishwav'
eng_filenames=os.listdir(eng_data_path)
eng_labels = []
eng_audio_vectors = [] 
for filename in eng_filenames: 
   eng_labels.append(int(filename.split("_")[0]))
   file_path = os.path.join(eng_data_path,filename)
   y,sr = librosa.load(file_path, sr=44100)
   eng_audio_vectors.append(y)

eng_labels = np.array(eng_labels)
eng_audio_feature = extract_audio_features(eng_audio_vectors)
eng_audio_feature = np.array(eng_audio_feature)

# %%
import xgboost as xgb
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
scaled_x_train = scaler.fit_transform(x_train_audio)

xgb_classifier = xgb.XGBClassifier(max_depth=6, learning_rate=0.008, objective='multi:softprob', 
                                   n_estimators=1200, sub_sample=0.8, num_class=len(emotion_labels),
                                   booster='gbtree', n_jobs=4)

xgb_classifier.fit(scaled_x_train,y_train)

scaled_x_test = scaler.transform(eng_audio_feature)
# Predict
y_pred = xgb_classifier.predict(scaled_x_test)
title = "Confusion matrix"
disp = plot_confusion_matrix(xgb_classifier,scaled_x_test,eng_labels,
                             display_labels=emotion_labels,
                             cmap=plt.cm.Blues,
                             normalize=None)
disp.ax_.set_title(title)
print(title)
plt.show()
 
print('Accuracy:',accuracy_score(y_pred, eng_labels))
# Out:
# Confusion matrix
# Accuracy: 0.35
